# %%
import numpy as np
import cv2
import os
from keras.models import Sequential
from keras.layers import Activation, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img, img_to_array, array_to_img

# %%
INPUT_WIDTH = 100
INPUT_HEIGHT = 100
BATCH_SIZE = 128
EPOCHS = 100
STEPS = 5
CATEGORY = 4

OK_DIR1 = "C:\\Users\\kaida\\deeplearning\\car\\data\\ok_body_only"
OK_DIR2 = "C:\\Users\\kaida\\deeplearning\\car\\data\\ok_other"
NG_DIR1 = "C:\\Users\\kaida\\deeplearning\\car\\data\\ng_kizu"
NG_DIR2 = "C:\\Users\\kaida\\deeplearning\\car\\data\\ng_hekomi"

# %%
def load_image(dir_name, label):
    x = []
    y = []
    files = os.listdir(dir_name)
    for file in files:
        img = cv2.imread(os.path.join(dir_name, file))
#        img = cv2.imread(os.path.join(dir_name, file), 0)
        # リサイズ
        img = cv2.resize(img, (INPUT_WIDTH, INPUT_HEIGHT))
        # 正規化
#        img = (img - np.mean(img)) / np.std(img)

        img_array = np.array(img_to_array(img))
        x.append(img_array)
        if label == 0:
            y.append([1, 0, 0, 0]) # OK1ラベル
        elif label == 1:
            y.append([0, 1, 0, 0]) # OK1ラベル
        elif label == 2:
            y.append([0, 0, 1, 0]) # NG1ラベル
        else:
            y.append([0, 0, 0, 1]) # NG2ラベル
    
    return (x, y)

# %%
x_train = []
y_train = []
x_test = []
y_test = []

# OK画像を読み込む
x_ok1, y_ok1 = load_image(OK_DIR1, 0)
x_ok2, y_ok2 = load_image(OK_DIR2, 1)
x_ng1, y_ng1 = load_image(NG_DIR1, 2)
x_ng2, y_ng2 = load_image(NG_DIR2, 3)

x_train = x_ok1 + x_ok2 + x_ng1 + x_ng2
y_train = y_ok1 + y_ok2 + y_ng1 + y_ng2
    
# np配列化
x_train = np.array(x_train)
y_train = np.array(y_train)

# kerasは0～1しか受け付けない
x_train = x_train / 255
y_train = y_train / 255

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range(10):
    plt.subplot(4, 5, i+1)
    plt.imshow(array_to_img(x_train[i]))
    plt.gray()
plt.show()

# %%
# 訓練データとテストデータを分割
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=None)

# %%
# モデルを作る
def cnn_model():
    model = Sequential()
    
    # 畳み込み層１
    model.add(Conv2D(32, (3, 3), padding="SAME", input_shape=[INPUT_WIDTH, INPUT_HEIGHT, 3], name="conv1"))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2, 2))) # -> 50 x 50
    
    # 畳み込み層２
    model.add(Conv2D(32, (3, 3), padding="SAME", name="conv2"))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2, 2))) # -> 25 x 25
    
    # 畳み込み層３
    model.add(Conv2D(64, (3, 3), padding="SAME", name="conv3"))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2, 2))) # -> 12 x 12
    model.add(Dropout(0.8))
    
    model.add(Flatten())
    # 全結合１
    model.add(Dense(64, name="dense1"))
    model.add(Activation("relu"))
    model.add(Dropout(0.5))

    # 全結合２
#    model.add(Dense(64, name="dense2"))
#    model.add(Activation("relu"))
#    model.add(Dropout(0.5))
    
    # 出力
    model.add(Dense(CATEGORY, name="output"))
    model.add(Activation("softmax"))
    
    return model

# %%
model = cnn_model()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 100, 100, 32)      896
# _________________________________________________________________
# activation_16 (Activation)   (None, 100, 100, 32)      0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 50, 50, 32)        9248
# _________________________________________________________________
# activation_17 (Activation)   (None, 50, 50, 32)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 25, 25, 64)        18496
# _________________________________________________________________
# activation_18 (Activation)   (None, 25, 25, 64)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                589888
# _________________________________________________________________
# activation_19 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 4)                 260
# _________________________________________________________________
# activation_20 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 618,788
# Trainable params: 618,788
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
train_gen = ImageDataGenerator(
#    rescale=1./255,
#    featurewise_center=False,
#    samplewise_center=False,
#    featurewise_std_normalization=False,
#    samplewise_std_normalization=False,
    rotation_range=180,
#    width_shift_range=0.2,
#    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
# 5/5 [==============================] - 12s - loss: 0.0037 - acc: 0.5439 - val_loss: 0.0050 - val_acc: 0.4531
# Epoch 95/100
# 5/5 [==============================] - 10s - loss: 0.0040 - acc: 0.5315 - val_loss: 0.0048 - val_acc: 0.5469
# Epoch 96/100
# 5/5 [==============================] - 10s - loss: 0.0036 - acc: 0.5885 - val_loss: 0.0048 - val_acc: 0.5234
# Epoch 97/100
# 5/5 [==============================] - 12s - loss: 0.0035 - acc: 0.6078 - val_loss: 0.0048 - val_acc: 0.4922
# Epoch 98/100
# 5/5 [==============================] - 11s - loss: 0.0036 - acc: 0.5752 - val_loss: 0.0048 - val_acc: 0.5625
# Epoch 99/100
# 5/5 [==============================] - 10s - loss: 0.0034 - acc: 0.6007 - val_loss: 0.0056 - val_acc: 0.5313
# Epoch 100/100
# 5/5 [==============================] - 13s - loss: 0.0036 - acc: 0.6033 - val_loss: 0.0051 - val_acc: 0.5000

# %%
def predict_message(predict):
    indice = np.argmax(predict)
    if indice in {0, 1}:
        print("ok (%s)" % str(predict[0] + predict[1]))
    elif indice in {2}:
        print("ng kizu (%s)" % str(predict[indice]))
    elif indice in {3}:
        print("ng hekomi (%s)" % str(predict[indice]))

# %%
predicts = model.predict(x_test)

# %%
plt.imshow(array_to_img(x_test[0]))
predict_message(predicts[0])
# Out:
# ok (0.720297)

# %%
plt.imshow(array_to_img(x_test[1]))
predict_message(predicts[1])
# Out:
# ok (0.508608)

# %%
plt.imshow(array_to_img(x_test[2]))
predict_message(predicts[2])
# Out:
# ng hekomi (0.791027)

# %%
plt.imshow(array_to_img(x_test[3]))
predict_message(predicts[3])
# Out:
# ng hekomi (0.358199)

# %%
plt.imshow(array_to_img(x_test[4]))
predict_message(predicts[4])
# Out:
# ok (0.733383)

# %%
plt.imshow(array_to_img(x_test[5]))
predict_message(predicts[5])
# Out:
# ok (0.732136)

# %%
json_string = model.to_json()
open(os.path.join('dragon_cnn_model.json'), 'w').write(json_string)
# Out:
# 4202

# %%
model.save_weights(os.path.join('dragon_cnn_model_weights.hdf5'))

# %%
def predict_ok_ng(x, y):
    correct = 0
    wrong = 0
    predicts = model.predict(x)
    for i in range(len(x)):
        indice = np.argmax(predicts[i])
        # ok
        if y[i][0] == 1 or y[i][1]:
            if indice in {0, 1}:
                correct += 1
            else:
                wrong += 1
        else:
            if indice in {2, 3}:
                correct += 1
            else:
                wrong += 1
    
    print("correct: %s / wrong: %s / acc: %s" % (str(correct), str(wrong), str(correct / (correct + wrong))))

# %%
predict_ok_ng(x_test, y_test)
# Out:
# correct: 69 / wrong: 59 / acc: 0.5390625

# %%
# 学習を可視化
import pickle
with open("history.pickle", mode='wb') as f:
    pickle.dump(history.history, f)

# %%
with open('history.pickle', mode='rb') as f:
    history = pickle.load(f)

plt.subplot(2,1,1)
plt.plot(history['loss'], "-", label="loss",)
plt.title('training')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='center right')

plt.subplot(2,1,2)
plt.plot(history['acc'], "-", label="acc",)
plt.ylabel('acc')
plt.legend(loc='center right')

plt.show()

plt.subplot(2,1,1)
plt.plot(history['val_loss'], "-", label="val_loss")
plt.title('validation')
plt.xlabel('epoch')
plt.ylabel('val_loss')
plt.legend(loc='center right')
plt.subplot(2,1,2)
plt.plot(history['val_acc'], "-", label="val_acc")
plt.ylabel('val_acc')
plt.legend(loc='center right')

plt.show()
